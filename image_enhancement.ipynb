# %% [markdown]
# <a href="https://colab.research.google.com/github/shreyash23/underwaterimagedetect/blob/main/image_enhancement.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/pksvision/Deep-WaveNet-Underwater-Image-Restoration.git
# Out:
# Cloning into 'Deep-WaveNet-Underwater-Image-Restoration'...
# remote: Enumerating objects: 150, done.
# remote: Counting objects: 100% (31/31), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 150 (delta 15), reused 31 (delta 15), pack-reused 119
# Receiving objects: 100% (150/150), 90.46 MiB | 16.46 MiB/s, done.
# Resolving deltas: 100% (40/40), done.

# %%
# %cd /content/Deep-WaveNet-Underwater-Image-Restoration/uie_uieb
# Out:
# /content/Deep-WaveNet-Underwater-Image-Restoration/uie_uieb

# %%
# !python test.py
# Out:
# Color correction module for underwater images
# 100% 31/31 [00:32<00:00,  1.05s/it, name: 828.png | old [hw]: 333/500 | new [hw]: 333/500]
# Total time taken in secs : 32.534329414367676
# Per image (avg): 1.049494497237667

# %%
from google.colab.patches import cv2_imshow

from skimage import io
import cv2 as cv


image1 = io.imread('./hazy_test/mud1.png')
image_1 = cv.cvtColor(image1, cv.COLOR_BGR2RGB)
cv2_imshow(image_1)


image2 = io.imread('./hazy_test/mud2.png')
image_2 = cv.cvtColor(image2, cv.COLOR_BGR2RGB)
cv2_imshow(image_2)
# Out:
# <PIL.Image.Image image mode=RGB size=762x472 at 0x7F032601E700>
# <PIL.Image.Image image mode=RGB size=766x361 at 0x7F0327874310>

# %%
image1 = io.imread('./facades/Ours_UIEB/mud1.png')
image_1 = cv.cvtColor(image1, cv.COLOR_BGR2RGB)
cv2_imshow(image_1)
image2 = io.imread('./facades/Ours_UIEB/mud2.png')
image_2 = cv.cvtColor(image2, cv.COLOR_BGR2RGB)
cv2_imshow(image_2)
# Out:
# <PIL.Image.Image image mode=RGB size=762x472 at 0x7F02F479AA30>
# <PIL.Image.Image image mode=RGB size=766x361 at 0x7F034B607A00>

# %%
# !python test.py
# Out:
# Color correction module for underwater images
# 100% 29/29 [00:31<00:00,  1.10s/it, name: 828.png | old [hw]: 333/500 | new [hw]: 333/500]
# Total time taken in secs : 31.779422760009766
# Per image (avg): 1.0958421641382678

# %%
from google.colab.patches import cv2_imshow

from skimage import io
import cv2 as cv


image = io.imread('./hazy_test/My project-1.png')
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
cv2_imshow(image_2)
# Out:
# <PIL.Image.Image image mode=RGB size=1080x1080 at 0x7F02F479A9D0>

# %%
image = io.imread('./facades/Ours_UIEB/My project-1.png')
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
cv2_imshow(image_2)
# Out:
# <PIL.Image.Image image mode=RGB size=1080x1080 at 0x7F02F479ABE0>
